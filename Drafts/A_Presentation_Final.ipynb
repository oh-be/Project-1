# %% [markdown]
# ![1321_cc-vs-gw-vs-wx-768px (1).jpg](attachment:b9d54474-5550-45fd-9999-8754f9390d2b.jpg)

# %% [markdown]
# # Group 2: Is climate change real?
# ***

# %% [markdown]
# ## What motivated us?
# #### - We've heard on the media and from different world leaders and leading scientists that there is a climate change crisis
# #### - We wanted to look at the avaliable data and analyze it to form our own conclusions
# ***

# %% [markdown]
# ## Question:
#  ### Is pollution (CO2) correlated with climate change (average global temperatures, natural disaster data)?
# ***

# %% [markdown]
# ### Hypothesis and Null Hypothesis:
#  #### - CO2 pollution is strongly correlated with and therefore influences global climate change.
#  #### - CO2 pollution is not correlated with and therefore does not influence global climate change.
# ***

# %% [markdown]
# ## Data Exploration and Cleanup Process
# ### (Go over EDA file)
# ***

# %% [markdown]
# # Raw Data

# %% [markdown]
# ![CO2(ppm) vs Year All Data 1000.png](attachment:68bb335a-5054-4000-b7e8-c892e77f5044.png)

# %% [markdown]
# ![CO2 vs Year All Data 1750.png](attachment:bf8820c9-5ba3-45f7-9fb7-8590d1ca454c.png)

# %% [markdown]
# ![Temp vs Year All Data 1750.png](attachment:3a36f788-5493-4ee2-afd9-79662dc23948.png)

# %% [markdown]
# ## Analysis of Final Data
#  ### Assumptions:
#  #### - Single source CO2 samples (ice cores) are representative of global CO2 values.
#  #### - Land average temp data is representative of bulk average temperature globally.
#  #### - Natural occurance data is representative of bulk average natural occurances globally.
#  ---
#  ### CO2 (ppm) vs Temp (Degrees C)
#  #### - r-squared shows a strong statistical correlation between the two variables
#  #### - the data shows there is a 89% reduction in variance when we take CO2 into account
#  #### - the variation in temperature can be explained by increase in CO2 levels
# ![CO2(ppm) vs Temp.png](TempVSCo2_HYC.png)
# ---
#  ### CO2 (ppm) vs Wildfire Events
#  #### - Weak correlation
#  #### - The data shows there is a 57% reduction in variance when we take CO2 into account
#  #### - We noticed there is a reduced correlation above 340 ppm/ the year 1980
# ![CO2(ppm) vs Wildfire (Occurrence).png](Wildfire_year_HYC.png)
# ---
#  ### CO2 (ppm) vs Flood Events
#  #### - Strong correlation
#  #### - The data shows there is a 89% reduction in variance when we take CO2 into account
#  #### - There is a reduced correlation around 360 ppm/ the year 1990
# ![CO2(ppm) vs Flood (Occurrence).png](Flood_year_HYC.png)
# ---
#  ### CO2 (ppm) vs Drought Events
#  #### - Weak correlation
#  #### - The data shows there is a 67% reduction in variance when we take CO2 into account
#  #### - The distribution of errors seem to be increasing with time
# ![CO2(ppm) vs Drought (Occurrence).png](Drought_year_HYC.png)
# ---
#  ### CO2 (ppm) vs Extreme Temperature Events
#  #### - Weak correlation
#  #### - The data shows there is a 68% reduction in variance when we take CO2 into account
#  #### - The distribution of errors seem to be increasing with time
# ![CO2(ppm) vs Extreme temperature (Occurrence).png](Extreme_Temperature_year_HYC.png)
# ---
#  ### CO2 (ppm) vs All Natural Disasters Events
#  #### - Strong correlation
#  #### - The data shows there is a 93% reduction in variance when we take CO2 into account
#  #### - There is a reduced correlation around 370 ppm/ the year 2000
# ![CO2(ppm) vs All natural disasters (Occurrence).png](All_Natural_Disaster_year_HYC.png)
# ---
#  ### CO2 (ppm) vs Extreme Weather Events
#  #### - Extreme weather events is defined as "unexpected, unusual, severe, or unseasonal weather; weather at the extremes of the historical distribution and the range that has been seen in the past."
#  #### - Strong correlation
#  #### - The data shows there is a 90% reduction in variance when we take CO2 into account
#  #### - We noticed there was a huge difference in the timeframe under 350 ppm and over 350 ppm
# ![CO2(ppm) vs Extreme weather (Occurrence).png](Extreme_Weather_year_HYC.png)
# ---
#  ### CO2 (Less than 350 ppm) vs Extreme Weather Events
#  #### - Strong correlation
#  #### - The data shows there is a 92% reduction in variance when we take CO2 into account
# ![CO2(ppm) Less than 350 vs Extreme weather (Occurrence),png.png](CO2(ppm)_LessThan350_HYC.png)
# ---
#  ### CO2 (Greater than 350 ppm) vs Extreme Weather Events
#  #### - Very weak correlation
#  #### - The data shows there is only a 6% reduction in variance when we take CO2 into account
# ![CO2(ppm) Greater than 350 vs Extreme weather (Occurrence).png](CO2(ppm)_GreaterThan350_HYC.png)
# ---

# %% [markdown]
# ## Conclusions and Implications of our Findings
# ![temp_co2_disaster.png](attachment:2cf1510a-51e1-486c-aaa0-5ca86342739e.png)
# ### If our analyses are right:
#    #### -There is statistical evidence that there is a relationship between Average Global Land Temperature and Atmospheric CO2 concentation.
#    #### - There is statistical evidencethat there is a relationship between occurence of natural disasters and Atmospheric CO2 concentration
#
# ### Alternatively:
#    #### - Late in project we learned that time series correlation should be done differently:
#    #### - Differencing, (Not absolute values) should be used to establish correlatoin
#    #### - Box-Cox transformation should be done to normalize variance
#    #### - Time Series data that is monotonically increasing will always have a strong correlation (mis-leading)
#    #### - Given additional time - we would repeat our analysis to determine if our conclusions are still valid.
# ***

# %% [markdown]
# # Another Way to look at the data

# %% [markdown]
# ![Screen Shot 2021-12-07 at 9.22.02 PM.png](attachment:d0f53d60-9d8a-4bf8-977b-c6e1e9e81ab3.png)

# %% [markdown]
# ## Article goes on to stat that if two sets of time series data are trending upward - then even random data will appear correlated...
#
# ## Then they tell us how to deal with the challenge...

# %% [markdown]
# ![Screen Shot 2021-12-07 at 8.57.30 PM.png](attachment:1c4e2568-ead1-490c-b555-b01bd830107b.png)

# %% [markdown]
# ![Screen Shot 2021-12-07 at 9.00.46 PM.png](attachment:d0a0526c-4a8f-451b-aeac-7b1bb23b5f31.png)

# %% [markdown]
# ## New Result wasn't as attractive... :  R^2 = .003

# %% [markdown]
# ![Delta_Temp vs Delta_CO2.png](attachment:44daa512-483b-4f98-84b4-6d89e6794209.png)

# %% [markdown]
# ## So we decided to make a definitive statement...
# ##
# ## "Earth's temperature is definitely trending up.  However, we are not smart enough (YET!) to prove it is statistically correlated with atmospheric CO2 concentration"

# %% [markdown]
# ---

# %% [markdown]
# ![66070115075__C2220044-6E5D-4C28-B33F-A81FD15D40FF.JPG](attachment:1ee1ddc3-59a3-4e35-b13f-0e656b75b41f.JPG)

# %% [markdown]
# ## Sources
# #### 1. Natural occurance data is from 1900 to 2015.
# #### - https://www.kaggle.com/dataenergy/natural-disaster-data
# #### 2. Mauna Loa CO2 annual mean data( text) or (CSV)
# #### - https://gml.noaa.gov/ccgg/trends/data.html
# #### 3. CO2 data from 1959 to 2015
# #### - https://www.ncei.noaa.gov/access/paleo-search/?dataTypeId=7
# #### 4. CO2 concentration from ice core samples
# #### - https://www.kaggle.com/berkeleyearth/climate-change-earth-surface-temperature-data
# #### 5. CO2 data from 1000 to 2004
# #### - https://www.ncei.noaa.gov/access/paleo-search/?dataTypeId=7
# #### 6. Conclusions and Interpretations
# #### - https://www.svds.com/avoiding-common-mistakes-with-time-series/
# ---
